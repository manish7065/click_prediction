# %%
from dotenv import load_dotenv   #for python-dotenv method
load_dotenv()                    #for python-dotenv method
import os

user_name = os.environ.get('TRIAL')
print(user_name)
# Out:
# trialtest

# %%
# !kaggle datasets files rxsraghavagrawal/instagram-reach
# kaggle datasets download -d rxsraghavagrawal/instagram-reach
# The above link can be downloaded from kaggle web dataset options
# Out:
# name                 size  creationDate
# -------------------  ----  -------------------
# instagram_reach.csv  40KB  2021-01-21 13:34:20

# %%
# To download data in to particular dir with unziping
kaggle.api.dataset_download_files("rxsraghavagrawal/instagram-reach", path="./data2", unzip=True, quiet=False)
# Out:
# ...
# 100%|██████████| 16.9k/16.9k [00:00<00:00, 1.02MB/s]

# %%
# searching for datasets on Kaggle about instagram research
datasets = kaggle.api.datasets_list(search="rxsraghavagrawal/instagram-reach/instagram_reach.csv")

print(datasets)
df = pd.DataFrame(datasets)
df
# Out:
# [{'subtitleNullable': '', 'creatorNameNullable': 'Raghav Agrawal', 'creatorUrlNullable': 'rxsraghavagrawal', 'totalBytesNullable': 17260, 'urlNullable': 'https://www.kaggle.com/datasets/rxsraghavagrawal/instagram-reach', 'licenseNameNullable': 'Unknown', 'descriptionNullable': None, 'ownerNameNullable': 'Raghav Agrawal', 'ownerRefNullable': 'rxsraghavagrawal', 'titleNullable': 'Instagram Reach', 'currentVersionNumberNullable': 1, 'usabilityRatingNullable': 0.47058824, 'id': 1110430, 'ref': 'rxsraghavagrawal/instagram-reach', 'subtitle': '', 'hasSubtitle': True, 'creatorName': 'Raghav Agrawal', 'hasCreatorName': True, 'creatorUrl': 'rxsraghavagrawal', 'hasCreatorUrl': True, 'totalBytes': 17260, 'hasTotalBytes': True, 'url': 'https://www.kaggle.com/datasets/rxsraghavagrawal/instagram-reach', 'hasUrl': True, 'lastUpdated': '2021-01-21T13:34:20.88Z', 'downloadCount': 1313, 'isPrivate': False, 'isFeatured': False, 'licenseName': 'Unknown', 'hasLicenseName': True, 'description': '', 'hasDe
# ...

# %% [markdown]
# # Blog
# [link](https://codesolid.com/kaggle-datasets/)

# %%
# !kaggle datasets list -s "air quality"
# Out:
# ref                                                             title                                     size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ---------------------------------------  -----  -------------------  -------------  ---------  ---------------
# epa/epa-historical-air-quality                                  Historical Air Quality                      0B  2019-02-12 00:35:35              0        302  0.7058824
# shrutibhargava94/india-air-quality-data                         India Air Quality Data                     5MB  2017-07-22 05:04:57          24657        356  0.85294116
# fedesoriano/air-quality-data-set                                 Air Quality Dataset                     248KB  2020-12-24 15:04:20           7469         64  1.0
# ...

# %%
import pandas as pd
datasets = kaggle.api.datasets_list(search="air quality")
pd.DataFrame(datasets)
# Out:
#                                      subtitleNullable  creatorNameNullable
# 0   Air Quality Data Collected at Outdoor Monitors...          Sohier Dane  \
# 1         India's air pollution levels over the years      Shruti Bhargava
# 2   Hourly averaged responses from an array of 5 m...          fedesoriano
# 3   Air Quality Index (AQI) and hourly data across...               Vopani
# 4         Country wise Daily AQI - Air Quality Index   Azmine Toushik Wasi
# 5   Different pollution levels in Madrid from 2001...        Diego Vicente
# 6        Downloaded data from https://airsofia.info/      Hristo Mavrodiev
# 7   https://archive.ics.uci.edu/ml/datasets/Air+Qu...                chsgl
# 8   Air quality monitoring data from northern Taiw...           Nelson Chu
# 9   Air Quality Monitoring in Vinnytsia city and r...        Vitalii Mokin
# 10  Air Quality Monitoring in Vinnytsia city and r...       Dima Shmundiak
# ...

# %%
# To download data in current folder
# !kaggle datasets download -d senapatirajesh/netflix-tv-shows-and-movies

# %%
# importing modules
import zipfile
import pandas as pd

with zipfile.ZipFile("netflix-tv-shows-and-movies.zip","r") as zip_ref:
    
    # extracting content in the zipfile
    zip_ref.extractall()

# reading the contents of the "NetFlix.csv"
df = pd.read_csv("NetFlix.csv")

# printing first 6 raws of the dataframe
df.head(6)
